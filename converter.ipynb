# %%
import os
#import cv2
import sys
import shutil

# %%
image_path = r"/Users/joselopez/Desktop/W3b_W0rk/portfolio_hugo/assets/img/personales"
os.makedirs(os.path.join(image_path, 'thumbnails'), exist_ok=True)
os.makedirs(os.path.join(image_path, 'full'), exist_ok=True)

thumbnails_path = os.path.join(image_path, 'thumbnails')
full_path = os.path.join(image_path, 'full')

image_files = [f for f in os.listdir(image_path) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.tiff', '.bmp'))]

count = 1
for image in image_files:

    image_og_path = os.path.join(image_path, image)
    
    image_thumb_path = os.path.join(thumbnails_path, str(count) + '.webp')
    image_full_path = os.path.join(full_path, str(count) + '.webp')
    
    # !ffmpeg -i {image_og_path} -vf "scale=400:-1:flags=lanczos" -c:v libwebp -quality 85 -method 6 -preset picture -lossless 0 {image_thumb_path}
    # !ffmpeg -i {image_og_path} -vf "scale=1920:-1:flags=lanczos" -c:v libwebp -quality 85 -preset photo -lossless 0 {image_full_path}
    
    count += 1
# Out:
# ffmpeg version 7.0.1 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
# ...
